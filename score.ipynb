# %%
from decimal import Decimal, ROUND_HALF_UP, ROUND_HALF_EVEN
score = [0,0,0]     #得点を入れる配列
grades = {}          #成績を入れる辞書
dic = {'y':True, 'yes':True, 'n':False, 'no':False}

while True:
    while True:
        try:
            ynq = dic[input('データを追加しますか？[y/n]').lower()]
            break
        except:
            print('y/nで入力してください')
            continue
    if ynq:
        name = input('氏名：')
        for i in range(3):
            while True:
                try:
                    score[i] = int(input('得点：'))
                    break
                except:
                    print('数字を入力してください')
                    continue
        grades[name] = tuple(score)
    else:
        break
for k,v in grades.items():
    print(k, '　平均：', Decimal(str(f)).quantize(Decimal('0'), rounding=ROUND_HALF_UP), '　最高：', max(v), '　最低：', min(v), sep='')
