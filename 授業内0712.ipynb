# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
import torch
print("GPUの名前:",torch.cuda.get_device_name(0))
print("GPUが使用可能か確認:",torch.cuda.is_available())
print("PyTorchで使用できるGPU(デバイス)数の確認",torch.cuda.device_count())
# Out:
# GPUの名前: Tesla T4
# GPUが使用可能か確認: True
# PyTorchで使用できるGPU(デバイス)数の確認 1

# %%
import time
start = time.time()

#ここに処理する内容

process_time = time.time() - start
print('time:{0:.3f} sec',format(process_time))
# Out:
# time:{0:.3f} sec 3.814697265625e-05
